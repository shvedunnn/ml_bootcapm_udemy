# %% [markdown]
# <a href="https://colab.research.google.com/github/shvedunnn/ml_bootcapm_udemy/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello
